# %% [markdown]
# <a href="https://colab.research.google.com/github/SiracencoSerghei/linear_algebra/blob/main/3.1_eigen_decomposition/3.1_5_aig_differences.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sympy import *
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ---
# # Code challenge: eigenDecomposition of matrix differences
# ---

# %%
A = np.random.randn(5,5)
A = A.T@A

B = np.random.randn(5,5)
B = B@B.T

D1,V1 = np.linalg.eig(A-B)
D2,V2 = np.linalg.eig(A@A - A@B - B@A + B@B)

print(np.round(D1,3)), print(' ')
print(np.round(D2,3)), print(' ')
print(np.round(D1**2,3)), print(' ')

print(np.round(V1-V2,3))
# Out:
# [ 4.554  1.934 -7.527 -5.388 -1.781]
#
# [56.657 29.029 20.742  3.739  3.174]
#
# [20.742  3.739 56.657 29.029  3.174]
#
# [[ 0.444 -1.158 -0.444  1.158  0.409]
#  [-0.074 -0.249  0.074  0.249  1.21 ]
#  [-0.49   0.462  0.49  -0.462  1.363]
#  [-0.464 -0.422  0.464  0.422  0.337]
#  [ 1.158  0.455 -1.158 -0.455  0.632]]

# %%
# sort eigenValues
sidx1 = np.argsort(abs(D1))
sidx2 = np.argsort(D1)
sidx3 = np.argsort(D2)
sidx4 = np.argsort(D1**2)

print(sidx1), print(' ')
print(sidx2), print(' ')
print(sidx3), print(' ')
print(sidx4), print(' ')
# Out:
# [4 1 0 3 2]
#
# [2 3 4 1 0]
#
# [4 3 2 1 0]
#
# [4 1 0 3 2]
# (None, None)

# %%
# now for actual sorting
D1 = D1[sidx1]
D2 = D2[sidx2]
print(D1),print(' ')
print(D1**2),print(' ')
print(D2),print(' ')

V1 = V1[:,sidx1]
V2 = V2[:,sidx2]

np.round(V1-V2,3)
# Out:
# [-1.78147747  1.9337129   4.55438632 -5.38784042 -7.52711719]
#
# [ 3.17366198  3.7392456  20.74243471 29.02882443 56.65749319]
#
# [20.74243471  3.7392456   3.17366198 29.02882443 56.65749319]
# array([[ 0.263, -0.   ,  0.146,  0.   ,  0.   ],
#        [ 0.12 , -0.   ,  1.089,  0.   ,  0.   ],
#        [ 1.31 , -0.   ,  0.052,  0.   ,  0.   ],
#        [ 0.365, -0.   , -0.028, -0.   , -0.   ],
#        [-0.256, -0.   ,  0.888,  0.   , -0.   ]])

# %%
print(np.round(V1,3)),print(' ')
print(np.round(V2,3)),print(' ')
# Out:
# [[ 0.204 -0.454 -0.059  0.704 -0.503]
#  [ 0.605  0.043  0.484  0.292  0.559]
#  [ 0.681  0.314 -0.629 -0.147 -0.139]
#  [ 0.168 -0.832 -0.197 -0.411  0.267]
#  [ 0.316 -0.024  0.572 -0.478 -0.586]]
#
# [[-0.059 -0.454 -0.204  0.704 -0.503]
#  [ 0.484  0.043 -0.605  0.292  0.559]
#  [-0.629  0.314 -0.681 -0.147 -0.139]
#  [-0.197 -0.832 -0.168 -0.411  0.267]
#  [ 0.572 -0.024 -0.316 -0.478 -0.586]]
# (None, None)

# %% [markdown]
# ---
# # EigenVectors of distinct eigenvalues
# ---

# %%
# Define a matrix A with distinct eigenvalues
A = np.array([[4, 1, 2],
              [1, 3, 0],
              [2, 0, 3]])

# Compute the eigenvalues and eigenvectors
eigenvalues, eigenvectors = np.linalg.eig(A)

# Print eigenvalues and eigenvectors
print("Eigenvalues:")
print(eigenvalues)

print("\nEigenvectors:")
print(eigenvectors)

# Verify that distinct eigenvalues correspond to distinct eigenvectors
# (eigenvectors should be linearly independent)

# Plot the eigenvectors
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Origin for the vectors
origin = np.zeros((3, 1))

# Plot each eigenvector
colors = ['r', 'g', 'b']
for i in range(3):
    ax.quiver(*origin, *eigenvectors[:, i], color=colors[i], label=f'v{i+1}', length=1)

# Plot settings
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_zlim([-1, 1])
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.legend()
plt.title("Eigenvectors of matrix A (Distinct Eigenvalues)")
plt.show()
# Out:
# Eigenvalues:
# [5.79128785 1.20871215 3.        ]
#
# Eigenvectors:
# [[-7.80454320e-01 -6.25212808e-01 -3.97205465e-16]
#  [-2.79603668e-01  3.49029782e-01 -8.94427191e-01]
#  [-5.59207335e-01  6.98059565e-01  4.47213595e-01]]

# %%
# Define a matrix A with distinct eigenvalues
A = np.array([[5, 1, 2],
              [1, 4, 0],
              [2, 0, 3]])

# Compute the eigenvalues and eigenvectors
eigenvalues, eigenvectors = np.linalg.eig(A)

# Print eigenvalues and corresponding null spaces (eigenvectors)
print("Eigenvalues and corresponding eigenvectors:")
for i in range(len(eigenvalues)):
    print(f"\nEigenvalue {i+1}: {eigenvalues[i]}")
    print(f"Eigenvector {i+1}:\n{eigenvectors[:, i]}")

    # Verify that (A - lambda*I) * v = 0 for the corresponding eigenvector
    null_space_check = np.dot(A - eigenvalues[i] * np.eye(A.shape[0]), eigenvectors[:, i])
    print(f"Check (A - lambda*I) * v = 0:\n{null_space_check}")

# Plot the eigenvectors
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Origin for the vectors
origin = np.zeros((3, 1))

# Plot each eigenvector
colors = ['r', 'g', 'b']
for i in range(3):
    ax.quiver(*origin, *eigenvectors[:, i], color=colors[i], label=f'v{i+1}', length=1)

# Plot settings
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_zlim([-1, 1])
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.legend()
plt.title("Eigenvectors and Null Spaces of A")
# Rotate the plot by adjusting the elevation and azimuthal angles
ax.view_init(elev=20, azim=75)

plt.show()
# Out:
# Eigenvalues and corresponding eigenvectors:
#
# Eigenvalue 1: 6.528917957294361
# Eigenvector 1:
# [-0.8226726  -0.32530617 -0.46624638]
# Check (A - lambda*I) * v = 0:
# [ 8.88178420e-16 -1.44328993e-15 -2.06997768e-15]
#
# Eigenvalue 2: 1.638531233814172
# Eigenvector 2:
# [-0.54739786  0.23180398  0.80412841]
# Check (A - lambda*I) * v = 0:
# [0.00000000e+00 7.77156117e-16 1.53447144e-15]
#
# Eigenvalue 3: 3.8325508088914644
# Eigenvector 3:
# [ 0.15351016 -0.91675668  0.36877068]
# Check (A - lambda*I) * v = 0:
# [ 1.11022302e-16 -8.88178420e-16 -9.68927525e-16]
