# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # Algebraic and geometric interpretations

# %%
# 2 dimentional vector
v2 = [3, -2]

# 3 dimentional vector

v3 = [4, -3, 2]

#row to column (or vice-versa):
v3t = np.transpose(v3)

print(v2)
print(v3)
print(v3t)
# Out:
# [3, -2]
# [4, -3, 2]
# [ 4 -3  2]

# %% [markdown]
# ## plot them

# %%
plt.plot([0, v2[0]], [0, v2[1]], label='v2', color='b', marker='o')
plt.axis('equal')
plt.text(v2[0], v2[1], 'v2', fontsize=12, ha='right', va='bottom')

plt.plot([-4, 4],[0, 0], 'k--')
plt.plot([0, 0], [-4, 4], 'k--')
plt.grid()
plt.axis((-4, 4, -4, 4))
plt.show()

# %% [markdown]
# ## plot the 3D vector

# %%
fig = plt.figure(figsize=plt.figaspect(1))
# ax = fig.add_subplot(projection='3d')
ax = plt.axes(projection = '3d')
ax.plot([0, v3[0]], [0, v3[1]],[0, v3[2]], linewidth=3)

# make the plot look nicer

ax.plot([0, 0], [0, 0], [-4, 4], 'k--')
ax.plot([0, 0],[-4, 4], [0, 0], 'k--')
ax.plot([-4, 4], [0, 0], [0, 0], 'k--')
plt.show()

# %% [markdown]
# # Vector addition / substraction

# %%
## two vectors in R2

# %%
v1 = np.array([3, -1])
v2 = np.array([2, 4])

v3 = v1 + v2

# %%
## plot them

# %%
plt.plot([0, v1[0]], [0, v1[1]], 'b', label='v1')
plt.plot([0, v2[0]]+v1[0],[0, v2[1]]+v1[1],'r',label='v2')
plt.plot([0, v3[0]],[0, v3[1]],'black',label='v1+v2')

plt.legend()
plt.axis('square')
plt.axis((-6, 6, -6, 6 ))
plt.grid()
plt.show()

# %% [markdown]
# # Vector-scalar multiplication

# %%
## vector and scalar
v1 = np.array([ 3, -1 ])
l  = 2.3
v1m = v1*l # scalar-modulated

## plot them
plt.plot([0, v1[0]],[0, v1[1]],'b',label='$v_1$')
plt.plot([0, v1m[0]],[0, v1m[1]],'r:',label='$\lambda v_1$')

plt.legend()
plt.axis('square')
axlim = max([max(abs(v1)),max(abs(v1m))])*1.5 # dynamic axis lim
plt.axis((-axlim,axlim,-axlim,axlim))
plt.grid()
plt.show()

# %% [markdown]
# # Vector-vector multiplication: the dot product

# %%
## many ways to compute the dot product

# v1 = np.array([ 1, 2, 3, 4, 5, 6 ])
v1 = np.array([ 1, 2, 3, 4, 5 ])
v2 = np.array([ 0, -4,  -3, 6, 5 ])

# method 1
dp1 = sum( np.multiply(v1,v2) )

# method 2
dp2 = np.dot( v1,v2 )

# method 3
dp3 = np.matmul( v1,v2 )

# method 4
dp4 = 0  # initialize

# loop over elements
for i in range(len(v1)):

    # multiply corresponding element and sum
    dp4 = dp4 + v1[i]*v2[i]


print(dp1,dp2,dp3,dp4)
# Out:
# 32 32 32 32

# %% [markdown]
# # Dot product properties: associative and distributive

# %%
## Distributive property

# create random vectors
n = 10
a = np.random.randn(n)
b = np.random.randn(n)
c = np.random.randn(n)

# the two results
res1 = np.dot( a , (b+c) )
res2 = np.dot(a,b) + np.dot(a,c)

# compare them
print([ res1,res2 ])
# Out:
# [0.5718413361871442, 0.5718413361871442]

# %%
## Associative property

# create random vectors
n = 5
a = np.random.randn(n)
b = np.random.randn(n)
c = np.random.randn(n)

# the two results
res1 = np.dot( a , np.dot(b,c) )
res2 = np.dot( np.dot(a,b) , c )

# compare them
print(res1)
print(res2)


### special cases where associative property works!
# 1) one vector is the zeros vector
# 2) a==b==c
# Out:
# [ 0.61570935 -0.41997001  1.17720147 -0.05257684  1.6208365 ]
# [ 2.06789886 -3.750373   -3.33812656  2.78451363  1.44715894]

# %% [markdown]
# # Dot products with matrix columns

# %%
rows = 4
columns = 6
A = np.random.randn(rows, columns)
B = np.random.randn(4, 6)

print(A)
print(' ')
print(B)

dps = np.zeros(6)
for i in range(6):
    dps[i] = np.dot(A[:, i], B[:, i])

print(' ')
print(dps)
# Out:
# [[-0.83456956 -1.58129707 -1.04881025 -0.21919922 -0.81637353  0.52335046]
#  [-0.34558728  1.72850011 -0.47835719 -0.155557   -2.62910236 -0.66306552]
#  [ 1.48215909 -1.5394293  -0.56041182  0.4972695   1.08674337  0.68020428]
#  [-1.11792308  1.17889557  0.37665343 -1.02861256  0.57786711 -1.26703327]]
#
# [[ 0.09790924  1.11767185 -0.29229897 -0.0430342   0.89722196  0.34266553]
#  [ 0.48671994  0.28451512 -0.04603594  1.07100506 -0.59819914 -0.44403667]
#  [ 1.60415855  0.47438119  0.67328951  0.99363881 -0.95417934 -1.11759024]
#  [-1.52419808  1.14401926 -0.34331529  1.15626067  0.74655509  0.52535407]]
#
# [ 3.83163811 -0.65718387 -0.17804251 -0.85240725  0.23472006 -0.95207119]

# %% [markdown]
# # Is the Dot product commutative?

# %%
A = np.random.randn(100)
B = np.random.randn(100)
# print(A)
# print(' ')
# print(B)

a = np.dot(A, B)
b = np.dot(B, A)
print(a, ' ', b, '\n ', a - b)

A = np.array([2, 4])
B = np.array([3, 5])

print(A)
print(B, '\n ')

v = np.dot(A, B.T)
w = np.dot(B, A.T)
print(v, ' ', w, '\n', v-w)
# Out:
# -7.355940306601967   -7.355940306601967
#   0.0
# [2 4]
# [3 5]
#
# 26   26
#  0

# %% [markdown]
# # Vector length

# %%
## a vector
v1 = np.array([ 1, 2, 3, 4, 5, 6 ])

## methods 1-4, just like with the regular dot product, e.g.:
vl1 = np.sqrt( sum( np.multiply(v1,v1)) )

## method 5: take the norm
vl2 = np.linalg.norm(v1)

print(vl1,vl2, '\n', vl2-vl1)
# Out:
# 9.539392014169456 9.539392014169456
#  0.0

# %% [markdown]
# # The dot product from a geometric perspective

# %%
## two vectors
v1 = np.array([ 2,  4, -3 ])
v2 = np.array([ 0, -3, -3 ])

## compute the angle (radians) between two vectors
ang = np.arccos( np.dot(v1,v2) / (np.linalg.norm(v1)*np.linalg.norm(v2)) )


## draw them
fig = plt.figure()
ax = plt.axes(projection='3d')

# Plot the vectors
ax.plot([0, v1[0]], [0, v1[1]], [0, v1[2]], 'b', label='v1')
ax.plot([0, v2[0]], [0, v2[1]], [0, v2[2]], 'r', label='v2')

# Set the limits for each axis
ax.set_xlim([-6, 6])
ax.set_ylim([-6, 6])
ax.set_zlim([-6, 6])

# Add labels and title
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
plt.title(f'Angle between vectors: {ang:.2f} rad.')

# Add legend
ax.legend()

# Show plot
plt.show()

# %%
## equivalence of algebraic and geometric dot product formulas

### two vectors
v1 = np.array([ 2,  4, -3 ])
v2 = np.array([ 0, -3, -3 ])


### algebraic
dp_a = np.dot( v1,v2 )

### geometric
dp_g = np.linalg.norm(v1)*np.linalg.norm(v2)*np.cos(ang)

### print dot product to command
print(dp_a)
print(dp_g)
# Out:
# -3
# -2.999999999999996

# %% [markdown]
# # Cauchy-Schwartz inequality

# %%
## create three vectors, one of which is dependent on another
a = np.random.randn(5)
b = np.random.randn(5)
c = np.random.randn(1)*a
print(a)
print(c)

# compute their dot product
aTb = np.dot(a,b)
aTc = np.dot(a,c)

# demonstrate the (in)equalities
print(f'{np.abs(aTb):.4f}, {np.linalg.norm(a)*np.linalg.norm(b):.4f}')
print(f'{np.abs(aTc):.4f}, {np.linalg.norm(a)*np.linalg.norm(c):.4f}')
# Out:
# [-1.85626278  1.39694871 -1.1970884  -0.14021366 -0.55379334]
# [ 4.7377965  -3.5654751   3.05536548  0.35787162  1.41346375]
# 0.3390, 6.0190
# 18.2659, 18.2659

# %% [markdown]
# # Dot product sign and scalar multiplication

# %%
## generate two R3 vectors
v1 = np.array([-3,4,5])
v2 = np.array([3,6,-3])

## generate two scalars
s1 = 2
s2 = 3

## compute dot product between the vectors
print(f'Original dot product: {np.dot(v1,v2)}')

## compute dot product between scaled vectors
print(s1*v1, s2*v2)
print(f'Scaled dot product: {np.dot(s1*v1, s2*v2)}')
# Out:
# Original dot product: 0
# [-6  8 10] [ 9 18 -9]
# Scaled dot product: 0

# %% [markdown]
# # Vector Hadamard multiplication

# %%
## create vectors
w1 = [ 1, 3, 5 ]
w2 = [ 3, 4, 2 ]

w3 = np.multiply(w1,w2)
print(w3)
# Out:
# [ 3 12 10]

# %% [markdown]
# # Vector outer product

# %%
v1 = np.array([  1, 2, 3 ])
v2 = np.array([ -1, 0, 1 ])

# outer product
o_p = np.outer(v1,v2)

# terrible programming, but helps conceptually:
op = np.zeros((len(v1),len(v2)))
for i in range(0,len(v1)):
    for j in range(0,len(v2)):
        op[i,j] = v1[i] * v2[j]

print(o_p)
print(op)
# Out:
# [[-1  0  1]
#  [-2  0  2]
#  [-3  0  3]]
# [[-1.  0.  1.]
#  [-2.  0.  2.]
#  [-3.  0.  3.]]

# %% [markdown]
# # Vector cross product

# %%
## create vectors
v1  = [ -3,  2, 5 ]
v2  = [  4, -3, 0 ]

## Python's cross-product function
v3a = np.cross( v1,v2 )

## "manual" method
v3b = [ [v1[1]*v2[2] - v1[2]*v2[1]],
        [v1[2]*v2[0] - v1[0]*v2[2]],
        [v1[0]*v2[1] - v1[1]*v2[0]] ]

print(v3a,v3b)


fig = plt.figure()
## ax = fig.add_subplot(projection='3d')
ax = plt.axes(projection = '3d')

## draw plane defined by span of v1 and v2
xx, yy = np.meshgrid(np.linspace(-10,10,10),np.linspace(-10,10,10))
z1 = (-v3a[0]*xx - v3a[1]*yy)/v3a[2]
ax.plot_surface(xx,yy,z1,alpha=.2)

## plot the two vectors
ax.plot([0, v1[0]],[0, v1[1]],[0, v1[2]],'k')
ax.plot([0, v2[0]],[0, v2[1]],[0, v2[2]],'green')
ax.plot([0, v3a[0]],[0, v3a[1]],[0, v3a[2]],'r')


ax.view_init(azim=150,elev=45)
plt.show()
# Out:
# [15 20  1] [[15], [20], [1]]

# %% [markdown]
# # Hermitian transpose (a.k.a. conjugate transpose)

# %%
## create a complex number
z = complex(3,4)
print(z)
## magnitude (length)
print( np.linalg.norm(z) )

## by transpose?
print( np.transpose(z)*z )

## by Hermitian transpose
print( np.transpose(z.conjugate())*z )


## complex vector
v = np.array( [ 3, 4j, 5+2j, complex(2,-5) ] )
print(v)
print( v.T )
print( np.transpose(v) )
print( np.transpose(v.conjugate()) )
# Out:
# (3+4j)
# 5.0
# (-7+24j)
# (25+0j)
# [3.+0.j 0.+4.j 5.+2.j 2.-5.j]
# [3.+0.j 0.+4.j 5.+2.j 2.-5.j]
# [3.+0.j 0.+4.j 5.+2.j 2.-5.j]
# [3.-0.j 0.-4.j 5.-2.j 2.+5.j]

# %% [markdown]
# # Unit vector

# %%
## vector
v1 = np.array([ -3, 6 ])
print(v1)

## mu
mu = 1/np.linalg.norm(v1)
print(mu)

v1n = v1*mu
print(v1n)

## plot them
plt.plot([0, v1n[0]],[0, v1n[1]],'r',label='v1-norm',linewidth=5)
plt.plot([0, v1[0]],[0, v1[1]],'b',label='v1')

## axis square
plt.axis('square')
plt.axis(( -6, 6, -6, 6 ))
plt.grid()
plt.legend()
plt.show()
# Out:
# [-3  6]
# 0.14907119849998599
# [-0.4472136   0.89442719]

# %% [markdown]
# # Dot product with Unit vectors

# %%
## create two random-integers vectors (R4)
n = 4
v1 = np.round(20*np.random.randn(4))
v2 = np.round(20*np.random.randn(4))
print(v1, '\n', v2)

## compute lengths of the individual vectors,
## and the magnitude of their dot product

v1m = np.sqrt(np.dot(v1, v1))
v2m = np.sqrt(np.dot(v2, v2))

## dpm before normalization: Combines both the magnitudes and 
## the cosine of the angle between the vectors.
dpm = np.abs(np.dot(v1, v2))

print(v1m, v2m, dpm)
print(' ')

## "normalize" the vectors
v1u = v1/v1m
v2u = v2/v2m
print(v1u,'\n', v2u)
print(' ')

## compute magnitude of that dot product

## dpm after normalization: Is purely the cosine of the angle 
## between the vectors and thus provides information only about 
## the directional relationship between v1 and v2, independent of their lengths.

dpm = np.abs(np.dot(v1u, v2u))

print(dpm)

## The normalized dot product (cosine of the angle) is particularly useful in 
## determining the similarity in direction between two vectors.
# Out:
# [ -2. -20.   7. -14.]
#  [-34.  15. -19.   1.]
# 25.475478405713993 41.7492514902962 379.0
#
# [-0.07850687 -0.78506867  0.27477404 -0.54954807]
#  [-0.81438586  0.35928788 -0.45509798  0.02395253]
#
# 0.35634294754858703

# %% [markdown]
# # Span

# %%
## set S
S1 = np.array([1, 1, 0])
S2 = np.array([1, 7, 0])

## vectors v and w
v = np.array([1, 2, 0])
w = np.array([3, 2, 1])

## draw vectors
fig = plt.figure()
## ax = fig.add_subplot(projection='3d')
ax = plt.axes(projection = '3d')
ax.plot([0, S1[0]],[0, S1[1]],[.1, S1[2]+.1],'r',linewidth=3)
ax.plot([0, S2[0]],[0, S2[1]],[.1, S2[2]+.1],'r',linewidth=3)

ax.plot([0, v[0]],[0, v[1]],[.1, v[2]+.1],'g',linewidth=3)
ax.plot([0, w[0]],[0, w[1]],[0, w[2]],'b')

## now draw plane
xx, yy = np.meshgrid(range(-15,16), range(-15,16))
cp = np.cross(S1,S2)
z1 = (-cp[0]*xx - cp[1]*yy)*1./cp[2]
ax.plot_surface(xx,yy,z1)

plt.show()
