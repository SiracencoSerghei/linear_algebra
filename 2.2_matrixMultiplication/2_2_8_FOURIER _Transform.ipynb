# %% [markdown]
# <a href="https://colab.research.google.com/github/SiracencoSerghei/linear_algebra/blob/main/2.2_matrixMultiplication/2_2_8_FOURIER%20_Transform.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# # Fourier transform via matrix multiplication
# ---

# %%
# Fourier transform

# The size of the DFT matrix and the length of the input signal.
n = 52

# This is the base of the complex exponential used in the DFT matrix.
# The imaginary unit is a fundamental concept in complex numbers.
# It is denoted as i in mathematics, where i**2 = −1
# In Python, 1j is used to represent this imaginary unit
omega = np.e**(-2*np.pi*1j/n)

# initialize a complex matrix
F_loop = np.zeros((n, n), dtype=complex)

for j in range(n):

  # The nested loops populate the matrix F where each element F_loop[j,k] is
  # computed as ωjk.
  for k in range(n):
    F_loop[j, k] = omega**(j * k)

omega = np.exp(-2 * np.pi * 1j / n)

# Create arrays for the indices
# Creates an array of integers from 0 to n−1n−1, representing the row/column indices.
j = np.arange(n)  # row indices (0 to n-1)
k = np.arange(n)  # column indices (0 to n-1)

# Use broadcasting to create the matrix
F_vectorized = omega ** (j[:, None] * k)

# Verify that they are the same
print(f'F_loop == F_vectorized is {np.allclose(F_loop, F_vectorized)}')  # Should print True

plt.imshow(F.real, cmap='jet')
plt.show()
# plt.imshow(abs(F))
# plt.colorbar()
# plt.show()

# create a random signal x of length n and compute its Fourier transform using
# matrix multiplication:
x = np.random.randn(n)

#  compare the results from X1 (DFT matrix method) and X2 (NumPy's FFT):
X1 = F@x
X2 = np.fft.fft(x)
print(f'X1 == X2: {np.allclose(X1, X2)}') # np.allclose(X1, X2): This checks if
  # the two results are almost equal, accounting for numerical precision differences.

# plot them
plt.figure()
plt.plot(abs(X1))
plt.plot(abs(X2), marker='o', color='r', linestyle='None')
plt.show()
plt.plot(F.real[:,25])
plt.show()
# Out:
# F_loop == F_vectorized is True
# X1 == X2: True

# %% [markdown]
# The Fourier transform can be computed using matrix multiplication, which is a fundamental approach used in discrete Fourier transforms (DFT). This method leverages the fact that the DFT can be represented as a matrix-vector multiplication. Here's how you can understand and compute the DFT via matrix multiplication.

# %%
import numpy as np

def dft_matrix(N):
    """Construct the DFT matrix of size N x N."""
    n = np.arange(N)
    k = n.reshape((N, 1))
    W = np.exp(-2j * np.pi * k * n / N)
    return W

def dft(x):
    """Compute the DFT of the input vector x using matrix multiplication."""
    N = len(x)
    W = dft_matrix(N)
    return np.dot(W, x)

# Example: DFT of a simple signal
x = np.array([1, 2, 3, 4])  # Example signal
X = dft(x)

print("Input signal:", x)
print("DFT (using matrix multiplication):", X)
# Out:
# Input signal: [1 2 3 4]
# DFT (using matrix multiplication): [10.+0.00000000e+00j -2.+2.00000000e+00j -2.-9.79717439e-16j
#  -2.-2.00000000e+00j]
