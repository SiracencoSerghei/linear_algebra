# %% [markdown]
# <a href="https://colab.research.google.com/github/SiracencoSerghei/linear_algebra/blob/main/2.3_Matrix_RANK/2.3_2_Rank_AtA_AAt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ---
# # Rank of A^TA and AA^T
# ---

# %%
# Matrix sizes
m = 14
n = 3

# Create matrix A
A = np.round(10 * np.random.randn(m, n))

# Compute AtA and AAt
AtA = A.T @ A
AAt = A @ A.T

# Get matrix sizes
sizeAtA = AtA.shape
sizeAAt = AAt.shape

# Print information about the matrices
print(AtA)
print('AtA: %dx%d, rank=%d' % (sizeAtA[0], sizeAtA[1], np.linalg.matrix_rank(AtA)))
print(AAt)
print('AAt: %dx%d, rank=%d' % (sizeAAt[0], sizeAAt[1], np.linalg.matrix_rank(AAt)))

# Visualization
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Plot AtA
sns.heatmap(AtA, annot=True, cmap="coolwarm", cbar=True, ax=axes[0])
axes[0].set_title(f"AtA (Size: {sizeAtA[0]}x{sizeAtA[1]}, Rank: {np.linalg.matrix_rank(AtA)})")

# Plot AAt
# sns.heatmap(AAt, cmap="coolwarm", cbar=True, annot=True, fmt=".2f")  # fmt=".2f" formats numbers to 2 decimal places
sns.heatmap(AAt, cmap="coolwarm", cbar=True, annot=False)
axes[1].set_title(f"AAt (Size: {sizeAAt[0]}x{sizeAAt[1]}, Rank: {np.linalg.matrix_rank(AAt)})")

plt.show()
# Out:
# [[1004.   14.  756.]
#  [  14. 1713.  372.]
#  [ 756.  372. 2371.]]
# AtA: 3x3, rank=3
# [[ 622.   -9. -330.  310. -202.  -65.  369.  196. -106.  114.  -53.  106.
#   -134.  -51.]
#  [  -9. 1325.  128. -484. -716. -250. -418.  358.  758. -138. -151. -141.
#   -240.   24.]
#  [-330.  128.  337. -221.  110. -160. -420. -145.  144. -235.  -93. -141.
#      8.  -57.]
#  [ 310. -484. -221.  329.  154.   72.  348.  -27. -328.  119.   37.  109.
#     24.  -27.]
#  [-202. -716.  110.  154.  488.   78.   18. -294. -368.  -38.   50.    8.
#    156.  -36.]
#  [ -65. -250. -160.   72.   78.  249.  251.   -4. -152.  198.  156.   97.
#    106.   99.]
#  [ 369. -418. -420.  348.   18.  251.  577.   96. -320.  310.  148.  195.
#     46.   69.]
#  [ 196.  358. -145.  -27. -294.   -4.   96.  197.  164.   79.   -5.   31.
#    -88.   33.]
#  [-106.  758.  144. -328. -368. -152. -320.  164.  452. -116.  -90. -106.
#   -120.   12.]
# ...
