# %% [markdown]
# <a href="https://colab.research.google.com/github/SiracencoSerghei/linear_algebra/blob/main/3.1_eigen_decomposition/3.1_4_power_diagonalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ---
# # Matrix powers via diagonalization
# ---

# %%
## matrix powers

A = np.random.rand(2,2)
print(A), print(' ')
print(A@A@A), print(' ')

# compute matrix power directly
print( np.linalg.matrix_power(A,3) ) # A@A@A
print(' ')

# and via eigendecomposition
D,V = np.linalg.eig(A)
D = np.diag(D)

# reproduce via diagonalization
print(V @ np.linalg.matrix_power(D,3) @ np.linalg.inv(V) )
# Out:
# [[0.34192174 0.1997472 ]
#  [0.02140103 0.73648552]]
#
# [[0.04604585 0.18285191]
#  [0.01959086 0.40723609]]
#
# [[0.04604585 0.18285191]
#  [0.01959086 0.40723609]]
#
# [[0.04604585 0.18285191]
#  [0.01959086 0.40723609]]

# %%
## eigenvalues of A and A^3

# create a symmetric matrix
A = np.random.rand(3,3)
A = A@A.T

D,V   = np.linalg.eig(A)
D3,V3 = np.linalg.eig( A@A@A )

# print(D), print(' ')
# print(D3), print(' ')

print(V), print(' ')
print(V3)

plt.subplot(221)
plt.imshow(V)
plt.axis('off')
plt.title('evecs of A')

plt.subplot(223)
plt.imshow(V3)
plt.axis('off')
plt.title('evecs of A^3')

plt.show()
# Out:
# [[ 0.73568531  0.67370249 -0.06994348]
#  [ 0.48507715 -0.5961285  -0.63978979]
#  [ 0.47272327 -0.43675596  0.76536066]]
#
# [[-0.73568531 -0.67370249 -0.06994348]
#  [-0.48507715  0.5961285  -0.63978979]
#  [-0.47272327  0.43675596  0.76536066]]

# %%
## plot the eigenvectors and eigenvalues

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# plot eigenvectors of A
ax.plot([0,V[0,0]],[0,V[1,0]],[0,V[2,0]],'r')
ax.plot([0,V[0,1]],[0,V[1,1]],[0,V[2,1]],'k')
ax.plot([0,V[0,2]],[0,V[1,2]],[0,V[2,2]],'b')

# plot eigenvectors of A^3
ax.plot([0,V3[0,0]],[0,V3[1,0]],[0,V3[2,0]],'r--')
ax.plot([0,V3[0,1]],[0,V3[1,1]],[0,V3[2,1]],'k--')
ax.plot([0,V3[0,2]],[0,V3[1,2]],[0,V3[2,2]],'b--')

plt.show()

## show the eigenvalues
plt.plot([1,2,3],D,'bs-',label='A')
plt.plot([1.1,2.1,3.1],D3,'rs-',label='A^3')
plt.title('Eigenvalues')
plt.legend()
plt.show()

# %%
print(D), print(' ')
print(D3), print(' ')
print(D**3)
# Out:
# [3.30273639 0.05473117 0.3259421 ]
#
# [3.60264721e+01 1.63947245e-04 3.46275203e-02]
#
# [3.60264721e+01 1.63947245e-04 3.46275203e-02]
